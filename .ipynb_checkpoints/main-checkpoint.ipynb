# %%
# Imports & Path Setup
import os
import json
from pprint import pprint
from pathlib import Path
import shutil # shutil for deleting directories

# Configuration
# Set this to True to force extractor, chunker, and embedder steps to re-run.
# This will delete previously generated files for these steps.
# The downloader will still skip if HTML files already exist.
FORCE_RERUN = False

# Path Setup
# Determine the root directory of the project
# This assumes the notebook is run from the project root or a sub-directory
# where 'data', 'chunks', and 'sample_outputs' are relative to the root.
root_dir = Path(os.getcwd())

# Define specific directories for data, extracted text, chunks, and sample outputs
data_dir = root_dir / "data"
extracted_dir = data_dir / "extracted"
chunks_dir = root_dir / "chunks"
chunks_file = chunks_dir / "all_chunks.json" # The file containing all chunked data
embedded_file = data_dir / "embedded_chunks.json" # The file containing all embedded chunks
sample_outputs_dir = root_dir / "sample_outputs" # Directory to save query responses

# Ensure all necessary output directories exist. Create them if they don't.
data_dir.mkdir(parents=True, exist_ok=True)
extracted_dir.mkdir(parents=True, exist_ok=True)
chunks_dir.mkdir(parents=True, exist_ok=True)
sample_outputs_dir.mkdir(parents=True, exist_ok=True)

# Expected Files
# List of companies and years for which 10-K filings are expected
companies = ["GOOGL", "MSFT", "NVDA"]
years = [2022, 2023, 2024]

# Generate expected file paths for downloaded HTML and extracted text files
expected_htmls = [data_dir / f"{c}_{y}_10K.html" for c in companies for y in years]
expected_txts = [extracted_dir / f"{c}_{y}_10K.txt" for c in companies for y in years]

# Helper Function
def files_exist(filepaths):
    """Checks if all specified files (Path objects) exist."""
    return all(f.exists() for f in filepaths)

print(f"--- Starting Main Pipeline (FORCE_RERUN = {FORCE_RERUN}) ---")

# Step 1: Downloader
# This step checks if all required HTML files exist. If not, it runs the downloader.
# The downloader itself has logic to skip individual files if they already exist.
if not files_exist(expected_htmls):
    print("Missing HTMLs. Running downloader...")
    # %run downloader.ipynb
    try:
        run_downloader() # Calling the main function from downloader.ipynb
    except NameError:
        print("Please make sure `run_downloader()` is defined in downloader.ipynb and you run that notebook first.")
else:
    print("All 10-K HTML files found. Skipping downloader.")

# Step 2: Extractor
# If FORCE_RERUN is True, it deletes existing extracted text files to force re-extraction.
if FORCE_RERUN and extracted_dir.exists():
    print("FORCE_RERUN is True: Deleting existing extracted .txt files to force extraction.")
    shutil.rmtree(extracted_dir, ignore_errors=True) # Delete the entire extracted directory
    extracted_dir.mkdir(parents=True, exist_ok=True) # Recreate an empty extracted directory

# Check if all expected extracted text files exist. If not, run the extractor.
if not files_exist(expected_txts):
    print("Running extractor to generate .txt files...")
    # %run extractor.ipynb
    try:
        run_extractor() # Call the main function from extractor.ipynb
    except NameError:
        print("Please make sure `run_extractor()` is defined in extractor.ipynb and you run that notebook first.")
else:
    print("All extracted .txt files found. Skipping extractor.")

# Step 3: Chunker
# If FORCE_RERUN is True, it deletes the existing chunks file to force re-chunking.
if FORCE_RERUN and chunks_file.exists():
    print("FORCE_RERUN is True: Deleting existing chunks file to force chunking.")
    if chunks_dir.exists():
        shutil.rmtree(chunks_dir, ignore_errors=True) # Delete the entire chunks directory
    chunks_dir.mkdir(parents=True, exist_ok=True) # Recreate an empty chunks directory

# Check if the 'all_chunks.json' file exists. If not, run the chunker.
if not chunks_file.exists():
    print("No chunks file found. Running chunker...")
    # %run chunker.ipynb
    try:
        run_chunker() # Call the main function from chunker.ipynb
    except NameError:
        print(" Please make sure `run_chunker()` is defined in chunker.ipynb and you run that notebook first.")
else:
    print("Chunks already exist. Skipping chunker.")

# Step 4: Embedder
# If FORCE_RERUN is True, it deletes the existing embedded chunks file to force re-embedding.
if FORCE_RERUN and embedded_file.exists():
    print("FORCE_RERUN is True: Deleting existing embeddings file to force embedding.")
    os.remove(embedded_file) # Delete the embedded_chunks.json file

# Check if the 'embedded_chunks.json' file exists. If not, run the embedder.
if not embedded_file.exists():
    print("Running embedder to generate vector embeddings...")
    # %run embedder.ipynb
    try:
        run_embedder() # Call the main function from embedder.ipynb
    except NameError:
        print(" Please make sure `run_embedder()` is defined in embedder.ipynb and you run that notebook first.")
else:
    print(" Embeddings already exist. Skipping embedder.")

# Step 5: Agent Query Engine
# Load the agent query engine, which defines the `agent_query` function.
print("\n Loading RAG Agent...")
# %run agent_query_engine.ipynb

#  Step 6: Ask Your Questions & Save Outputs
# Define a list of queries to run, covering all required types.
test_queries = [
    {
        "name": "Basic Metrics",
        "query": "What was Microsoft's total revenue in 2023?",
        "filename": "microsoft_revenue_2023.json"
    },
    {
        "name": "YoY Comparison",
        "query": "How did NVIDIA's data center revenue grow from 2022 to 2023?",
        "filename": "nvidia_datacenter_growth_2022_2023.json"
    },
    {
        "name": "Cross-Company Analysis",
        "query": "Which company had the highest operating margin in 2023?",
        "filename": "highest_operating_margin_2023.json"
    },
    {
        "name": "Segment Analysis",
        "query": "What percentage of Google's revenue came from cloud in 2023?",
        "filename": "google_cloud_revenue_percentage_2023.json"
    },
    {
        "name": "AI Strategy",
        "query": "Compare AI investments mentioned by all three companies (Google, Microsoft, NVIDIA) in their 2024 10-Ks.",
        "filename": "ai_investments_comparison_2024.json"
    }
]

# Iterate through each query, execute it, and save the response.
for query_info in test_queries:
    query_name = query_info["name"]
    query_string = query_info["query"]
    output_filename = query_info["filename"]
    output_file_path = sample_outputs_dir / output_filename

    print(f"\n--- Testing with a {query_name} query ---")
    print(f" Querying agent: {query_string}")

    response = None # Initialize response to None for error handling
    try:
        response = agent_query(query_string) # Call the agent_query function

        # Print decomposed sub-queries if available
        if response and 'sub_queries' in response and response['sub_queries']:
            print("\n--- Decomposed Sub-queries: ---")
            for sq in response['sub_queries']:
                
                print(f"  - {sq}")
            print("--------------------------------------------------")

        # Print the final answer in a human-readable format
        print("\n Final Answer:")
        print(json.dumps(response, indent=2))

    except NameError:
        print(" Error: `agent_query` function not found. Make sure `agent_query_engine.ipynb` ran successfully.")
    except Exception as e:
        print(f" Error during query execution for '{query_name}': {e}")

    # Step 7: Save to sample_outputs
    try:
        if response: # Only attempt to save if a response was generated
            with open(output_file_path, "w", encoding="utf-8") as f:
                json.dump(response, f, indent=2)
            print(f"\n Response saved to {output_file_path}")
        else:
            print(f"\n Could not save response to {output_file_path} because no response was generated for '{query_name}'.")
    except Exception as e:
        print(f"\n Error saving response to {output_file_path}: {e}")

print("\n--- Main Pipeline Finished ---")
# Out:
# --- Starting Main Pipeline (FORCE_RERUN = False) ---
# All 10-K HTML files found. Skipping downloader.
# All extracted .txt files found. Skipping extractor.
# Chunks already exist. Skipping chunker.
#  Embeddings already exist. Skipping embedder.
#
#  Loading RAG Agent...
#
# --- Testing with a simple query ---
#
# --- Decomposed Sub-queries for 'What was Microsoft's total revenue in 2023?': ---
#   1. What was Microsoft's total revenue in 2023?
# --------------------------------------------------
#
# --- All Retrieved Chunks (before deduplication): ---
#   Company: MSFT, Year: 2022, Score: 0.7022, Excerpt: ings, was as follows: (In millions) Year Ended June 30, 2022 2021 2020 Server products and cloud ser...
#   Company: MSFT, Year: 2022, Score: 0.6913, Excerpt: th fiscal year 2021 included: • Microsoft Cloud (formerly commercial cloud) revenue increased 32% to...
#   Company: MSFT, Year: 2024, Score: 0.6869, Excerpt: d cloud services revenue growth Revenue from Windows Commercial products and cloud services, compris...
# ----------------------------------------------------
# {'answer': "Based on the provided context from Microsoft's 10-K filings, the "
#            'total revenue for 2023 is not explicitly stated. However, we can '
#            'infer the total revenue for 2023 from the provided information.\n'
#            '\n'
#            'The total revenue for 2022 is $198,270 million, and the total '
#            'revenue for 2024 is $245,122 million. To find the total revenue '
#            'for 2023, we can use the percentage change in revenue between 2022 '
#            'and 2024.\n'
#            '\n'
#            'The percentage change in revenue between 2022 and 2024 is 16% '
#            '($245,122 million - $198,270 million) / $198,270 million. To find '
#            'the total revenue for 2023, we can multiply the total revenue for '
#            '2022 by (1 + 0.16) or 1.16.\n'
#            '\n'
#            'Total revenue for 2023 = $198,270 million x 1.16 = $230,111 '
#            'million\n'
#            '\n'
#            'Therefore, the total revenue for Microsoft in 2023 is '
#            'approximately $230,111 million.',
#  'query': "What was Microsoft's total revenue in 2023?",
#  'reasoning': 'Original query processed as a single search.\n'
#               "Retrieving information for sub-query: 'What was Microsoft's "
#               "total revenue in 2023?'\n"
#               'Used Groq model to synthesize answer from combined retrieved '
#               'context.',
#  'sources': [{'company': 'MSFT',
#               'excerpt': 'ings, was as follows: (In millions) Year Ended '
#                          'June\xa030, 2022 2021 2020 Server products and cloud '
#                          'services $ 67,321 $ 52,589 $ 41,379 Office products '
#                          'and cloud services 44,862 39,872 35,316 Windows '
#                          '24,761 22,488 21,510 Gaming 16,230 15,370 11,575 '
#                          'LinkedIn 13,816 10,289 8,077 Search and news '
#                          'advertisi...',
#               'fiscal_year': 'N/A',
#               'score': 0.70220318518741,
#               'year': '2022'},
#              {'company': 'MSFT',
#               'excerpt': 'th fiscal year 2021 included: • Microsoft Cloud '
#                          '(formerly commercial cloud) revenue increased 32% to '
#                          '$91.2 billion. • Office Commercial products and '
#                          'cloud services revenue increased 13% driven by '
#                          'Office 365 Commercial growth of 18%. • Office '
#                          'Consumer products and cloud services revenue '
#                          'increased 11%...',
#               'fiscal_year': 'N/A',
#               'score': 0.6912652576607645,
#               'year': '2022'},
#              {'company': 'MSFT',
#               'excerpt': 'd cloud services revenue growth Revenue from Windows '
#                          'Commercial products and cloud services, comprising '
#                          'volume licensing of the Windows operating system, '
#                          'Windows cloud services, and other Windows commercial '
#                          'offerings Devices revenue growth Revenue from '
#                          'Devices, including Surface, HoloLens, and PC ac...',
#               'fiscal_year': 'N/A',
#               'score': 0.6869078033537748,
#               'year': '2024'}],
#  'sub_queries': ["What was Microsoft's total revenue in 2023?"]}
#
# --- Testing with a comparative query (YoY growth) ---
#
# --- Decomposed Sub-queries for 'How did NVIDIA's data center revenue grow from 2022 to 2023?': ---
#   1. What is NVIDIA's data center revenue in 2022?
#   2. What is NVIDIA's data center revenue in 2023?
#   3. What is the change in NVIDIA's data center revenue from 2022 to 2023?
# --------------------------------------------------
#
# --- All Retrieved Chunks (before deduplication): ---
#   Company: NVDA, Year: 2023, Score: 0.7548, Excerpt: and and $1.13 billion for inventory purchase obligations in excess of our demand expectations. Opera...
#   Company: NVDA, Year: 2024, Score: 0.7525, Excerpt:  Data Center, Gaming, Professional Visualization, and Automotive. Revenue for fiscal year 2024 was $...
#   Company: NVDA, Year: 2024, Score: 0.7301, Excerpt:  "Compute & Networking" and "Graphics." Refer to Note 17 of the Notes to the Consolidated Financial ...
#   Company: NVDA, Year: 2023, Score: 0.7684, Excerpt: and and $1.13 billion for inventory purchase obligations in excess of our demand expectations. Opera...
#   Company: NVDA, Year: 2024, Score: 0.7545, Excerpt:  Data Center, Gaming, Professional Visualization, and Automotive. Revenue for fiscal year 2024 was $...
#   Company: NVDA, Year: 2024, Score: 0.7371, Excerpt:  "Compute & Networking" and "Graphics." Refer to Note 17 of the Notes to the Consolidated Financial ...
#   Company: NVDA, Year: 2023, Score: 0.7395, Excerpt: and and $1.13 billion for inventory purchase obligations in excess of our demand expectations. Opera...
#   Company: NVDA, Year: 2024, Score: 0.7338, Excerpt:  "Compute & Networking" and "Graphics." Refer to Note 17 of the Notes to the Consolidated Financial ...
#   Company: NVDA, Year: 2024, Score: 0.7328, Excerpt:  Data Center, Gaming, Professional Visualization, and Automotive. Revenue for fiscal year 2024 was $...
# ----------------------------------------------------
# {'answer': "Based on the provided context from NVIDIA's 10-K filings, here is "
#            'the answer to the question:\n'
#            '\n'
#            "NVIDIA's data center revenue grew from $10.67 billion in fiscal "
#            'year 2022 to $15.01 billion in fiscal year 2023, representing a '
#            'growth rate of 41%. This significant growth was driven by '
#            "hyperscalers and cloud usage of NVIDIA's accelerated computing "
#            'platforms and networking portfolio.\n'
#            '\n'
#            'Note that the provided context does not include data center '
#            'revenue for 2022, but rather mentions that data center revenue for '
#            'fiscal year 2023 was up 41% from fiscal year 2022.',
#  'query': "How did NVIDIA's data center revenue grow from 2022 to 2023?",
#  'reasoning': 'Original query decomposed into 3 sub-queries.\n'
#               "Retrieving information for sub-query: 'What is NVIDIA's data "
#               "center revenue in 2022?'\n"
#               "Retrieving information for sub-query: 'What is NVIDIA's data "
#               "center revenue in 2023?'\n"
#               "Retrieving information for sub-query: 'What is the change in "
#               "NVIDIA's data center revenue from 2022 to 2023?'\n"
#               'Used Groq model to synthesize answer from combined retrieved '
#               'context.',
#  'sources': [{'company': 'NVDA',
#               'excerpt': 'and and $1.13 billion for inventory purchase '
#                          'obligations in excess of our demand expectations. '
#                          'Operating expenses, which included a $1.35 billion '
#                          'acquisition termination charge related to the Arm '
#                          'transaction, were up 50% from a year ago. The '
#                          'increase also reflected compensation, data center '
#                          'infrastr...',
#               'fiscal_year': 'N/A',
#               'score': 0.7683977365204872,
#               'year': '2023'},
#              {'company': 'NVDA',
#               'excerpt': ' Data Center, Gaming, Professional Visualization, '
#                          'and Automotive. Revenue for fiscal year 2024 was '
#                          '$60.9 billion, up 126% from a year ago. Data Center '
#                          'revenue for fiscal year 2024 was up 217%. Strong '
#                          'demand was driven by enterprise software and '
#                          'consumer internet applications, and multiple '
#                          'industry v...',
#               'fiscal_year': 'N/A',
#               'score': 0.7545359195433536,
#               'year': '2024'},
#              {'company': 'NVDA',
#               'excerpt': ' "Compute & Networking" and "Graphics." Refer to '
#                          'Note 17 of the Notes to the Consolidated Financial '
#                          'Statements in Part IV, Item 15 of this Annual Report '
#                          'on Form 10-K for additional information. '
#                          'Headquartered in Santa Clara, California, NVIDIA was '
#                          'incorporated in California in April 1993 and '
#                          'reincorp...',
#               'fiscal_year': 'N/A',
#               'score': 0.7371248059571589,
#               'year': '2024'}],
#  'sub_queries': ["What is NVIDIA's data center revenue in 2022?",
#                  "What is NVIDIA's data center revenue in 2023?",
#                  "What is the change in NVIDIA's data center revenue from 2022 "
#                  'to 2023?']}
#
# --- Testing with a complex cross-company/segment query ---
#
# --- Decomposed Sub-queries for 'Compare cloud revenue growth rates across all three companies (Google, Microsoft, NVIDIA) from 2022 to 2023.': ---
#   1. Google cloud revenue 2022
#   2. Google cloud revenue 2023
#   3. Microsoft cloud revenue 2022
#   4. Microsoft cloud revenue 2023
#   5. NVIDIA data center revenue 2022
#   6. NVIDIA data center revenue 2023
# --------------------------------------------------
#
# --- All Retrieved Chunks (before deduplication): ---
#   Company: GOOGL, Year: 2024, Score: 0.7764, Excerpt: billion from 2023 to 2024. The growth was primarily driven by an increase in subscription revenues, ...
#   Company: GOOGL, Year: 2023, Score: 0.7529, Excerpt: increased sales of Pixel devices. The decrease in platform revenues was primarily due to Google Play...
#   Company: GOOGL, Year: 2023, Score: 0.7223, Excerpt: bers, and fluctuations in the timing of product launches. Google Cloud Google Cloud revenues are com...
#   Company: GOOGL, Year: 2024, Score: 0.7840, Excerpt: billion from 2023 to 2024. The growth was primarily driven by an increase in subscription revenues, ...
#   Company: GOOGL, Year: 2023, Score: 0.7554, Excerpt: increased sales of Pixel devices. The decrease in platform revenues was primarily due to Google Play...
#   Company: GOOGL, Year: 2023, Score: 0.7230, Excerpt:  was $101.7 billion for the year ended December 31, 2023. • Capital expenditures, which primarily re...
#   Company: MSFT, Year: 2022, Score: 0.7956, Excerpt: in every country around the world. Our platforms and tools help drive small business productivity, l...
#   Company: MSFT, Year: 2022, Score: 0.7567, Excerpt: ings, was as follows: (In millions) Year Ended June 30, 2022 2021 2020 Server products and cloud ser...
#   Company: MSFT, Year: 2023, Score: 0.7530, Excerpt: ons) Year Ended June 30, 2023 2022 2021 Server products and cloud services $ 79,970 $ 67,350 $ 52,58...
#   Company: MSFT, Year: 2022, Score: 0.7947, Excerpt: in every country around the world. Our platforms and tools help drive small business productivity, l...
#   Company: MSFT, Year: 2024, Score: 0.7630, Excerpt: d-based solutions, content, and other services to people and businesses; licensing and supporting an...
#   Company: MSFT, Year: 2023, Score: 0.7592, Excerpt: ons) Year Ended June 30, 2023 2022 2021 Server products and cloud services $ 79,970 $ 67,350 $ 52,58...
#   Company: NVDA, Year: 2023, Score: 0.7474, Excerpt: and and $1.13 billion for inventory purchase obligations in excess of our demand expectations. Opera...
#   Company: NVDA, Year: 2024, Score: 0.7408, Excerpt:  "Compute & Networking" and "Graphics." Refer to Note 17 of the Notes to the Consolidated Financial ...
#   Company: NVDA, Year: 2024, Score: 0.7397, Excerpt:  Data Center, Gaming, Professional Visualization, and Automotive. Revenue for fiscal year 2024 was $...
#   Company: NVDA, Year: 2023, Score: 0.7567, Excerpt: and and $1.13 billion for inventory purchase obligations in excess of our demand expectations. Opera...
#   Company: NVDA, Year: 2024, Score: 0.7457, Excerpt:  "Compute & Networking" and "Graphics." Refer to Note 17 of the Notes to the Consolidated Financial ...
#   Company: NVDA, Year: 2024, Score: 0.7379, Excerpt:  Data Center, Gaming, Professional Visualization, and Automotive. Revenue for fiscal year 2024 was $...
# ----------------------------------------------------
# {'answer': 'Based on the provided context, here is a comprehensive answer to '
#            'the question:\n'
#            '\n'
#            'Cloud revenue growth rates across all three companies (Google, '
#            'Microsoft, NVIDIA) from 2022 to 2023 can be compared as follows:\n'
#            '\n'
#            '* Google Cloud: Google Cloud revenues increased $6.8 billion from '
#            '2022 to 2023, representing a growth rate of 34.6% (from $26.28 '
#            'billion to $33.08 billion).\n'
#            '* Microsoft Cloud: Microsoft Cloud revenue increased $46.2 billion '
#            'from 2022 to 2023, representing a growth rate of 23% (from $91.2 '
#            'billion to $137.4 billion).\n'
#            "* NVIDIA Cloud: NVIDIA's Data Center revenue for fiscal year 2024 "
#            'was up 217% from a year ago, but the exact growth rate from 2022 '
#            'to 2023 is not provided in the context.\n'
#            '\n'
#            "In summary, Google Cloud's growth rate from 2022 to 2023 was "
#            "34.6%, while Microsoft Cloud's growth rate was 23%. NVIDIA's Data "
#            'Center revenue growth rate for fiscal year 2024 was 217%, but the '
#            'exact growth rate from 2022 to 2023 is not provided.',
#  'query': 'Compare cloud revenue growth rates across all three companies '
#           '(Google, Microsoft, NVIDIA) from 2022 to 2023.',
#  'reasoning': 'Original query decomposed into 6 sub-queries.\n'
#               "Retrieving information for sub-query: 'Google cloud revenue "
#               "2022'\n"
#               "Retrieving information for sub-query: 'Google cloud revenue "
#               "2023'\n"
#               "Retrieving information for sub-query: 'Microsoft cloud revenue "
#               "2022'\n"
#               "Retrieving information for sub-query: 'Microsoft cloud revenue "
#               "2023'\n"
#               "Retrieving information for sub-query: 'NVIDIA data center "
#               "revenue 2022'\n"
#               "Retrieving information for sub-query: 'NVIDIA data center "
#               "revenue 2023'\n"
#               'Used Groq model to synthesize answer from combined retrieved '
#               'context.',
#  'sources': [{'company': 'MSFT',
#               'excerpt': 'in every country around the world. Our platforms and '
#                          'tools help drive small business productivity, large '
#                          'business competitiveness, and public-sector '
#                          'efficiency. They also support new startups, improve '
#                          'educational and health outcomes, and empower human '
#                          'ingenuity. We generate revenue by offering a wid...',
#               'fiscal_year': 'N/A',
#               'score': 0.7955780957515081,
#               'year': '2022'},
#              {'company': 'GOOGL',
#               'excerpt': 'billion from 2023 to 2024. The growth was primarily '
#                          'driven by an increase in subscription revenues, '
#                          'largely from growth in the number of paid '
#                          'subscribers for YouTube services followed by Google '
#                          'One. Google Cloud Google Cloud revenues increased '
#                          '$10.1 billion from 2023 to 2024 primarily driven by '
#                          'grow...',
#               'fiscal_year': 'N/A',
#               'score': 0.7839549047105683,
#               'year': '2024'},
#              {'company': 'MSFT',
#               'excerpt': 'd-based solutions, content, and other services to '
#                          'people and businesses; licensing and supporting an '
#                          'array of software products; delivering relevant '
#                          'online advertising to a global audience; and '
#                          'designing and selling devices. Our most significant '
#                          'expenses are related to compensating employees; '
#                          'suppor...',
#               'fiscal_year': 'N/A',
#               'score': 0.7630304038960053,
#               'year': '2024'},
#              {'company': 'MSFT',
#               'excerpt': 'ons) Year Ended June 30, 2023 2022 2021 Server '
#                          'products and cloud services $ 79,970 $ 67,350 $ '
#                          '52,589 Office products and cloud services 48,728 '
#                          '44,862 39,872 Windows 21,507 24,732 22,488 Gaming '
#                          '15,466 16,230 15,370 LinkedIn 15,145 13,816 10,289 '
#                          'Search and news advertising 12,208 11,591 9,267 '
#                          'Enterpr...',
#               'fiscal_year': 'N/A',
#               'score': 0.7592306010896235,
#               'year': '2023'},
#              {'company': 'MSFT',
#               'excerpt': 'ings, was as follows: (In millions) Year Ended '
#                          'June\xa030, 2022 2021 2020 Server products and cloud '
#                          'services $ 67,321 $ 52,589 $ 41,379 Office products '
#                          'and cloud services 44,862 39,872 35,316 Windows '
#                          '24,761 22,488 21,510 Gaming 16,230 15,370 11,575 '
#                          'LinkedIn 13,816 10,289 8,077 Search and news '
#                          'advertisi...',
#               'fiscal_year': 'N/A',
#               'score': 0.7566720524130208,
#               'year': '2022'},
#              {'company': 'NVDA',
#               'excerpt': 'and and $1.13 billion for inventory purchase '
#                          'obligations in excess of our demand expectations. '
#                          'Operating expenses, which included a $1.35 billion '
#                          'acquisition termination charge related to the Arm '
#                          'transaction, were up 50% from a year ago. The '
#                          'increase also reflected compensation, data center '
#                          'infrastr...',
#               'fiscal_year': 'N/A',
#               'score': 0.7566519061505355,
#               'year': '2023'},
#              {'company': 'GOOGL',
#               'excerpt': 'increased sales of Pixel devices. The decrease in '
#                          'platform revenues was primarily due to Google Play, '
#                          'driven by the fee structure changes we announced in '
#                          '2021 as well as a decrease in buyer spending. '
#                          'Additionally, the overall increase in Google '
#                          'subscriptions, platforms, and devices revenues was '
#                          'adve...',
#               'fiscal_year': 'N/A',
#               'score': 0.7553930252987062,
#               'year': '2023'},
#              {'company': 'NVDA',
#               'excerpt': ' "Compute & Networking" and "Graphics." Refer to '
#                          'Note 17 of the Notes to the Consolidated Financial '
#                          'Statements in Part IV, Item 15 of this Annual Report '
#                          'on Form 10-K for additional information. '
#                          'Headquartered in Santa Clara, California, NVIDIA was '
#                          'incorporated in California in April 1993 and '
#                          'reincorp...',
#               'fiscal_year': 'N/A',
#               'score': 0.7457205117059804,
#               'year': '2024'},
#              {'company': 'NVDA',
#               'excerpt': ' Data Center, Gaming, Professional Visualization, '
#                          'and Automotive. Revenue for fiscal year 2024 was '
#                          '$60.9 billion, up 126% from a year ago. Data Center '
#                          'revenue for fiscal year 2024 was up 217%. Strong '
#                          'demand was driven by enterprise software and '
#                          'consumer internet applications, and multiple '
#                          'industry v...',
#               'fiscal_year': 'N/A',
#               'score': 0.7397380404396672,
#               'year': '2024'},
#              {'company': 'GOOGL',
#               'excerpt': ' was $101.7 billion for the year ended December 31, '
#                          '2023. • Capital expenditures, which primarily '
#                          'reflected investments in technical infrastructure, '
#                          'were $32.3 billion for the year ended December 31, '
#                          '2023. • As of December\xa031, 2023, we had 182,502 '
#                          'employees. Financial Results Revenues The following '
#                          '...',
#               'fiscal_year': 'N/A',
#               'score': 0.7230470704981811,
#               'year': '2023'},
#              {'company': 'GOOGL',
#               'excerpt': 'bers, and fluctuations in the timing of product '
#                          'launches. Google Cloud Google Cloud revenues are '
#                          'comprised of the following: • Google Cloud Platform, '
#                          'which generates consumption-based fees and '
#                          'subscriptions for infrastructure, platform, and '
#                          'other services. These services provide access to '
#                          'solutions ...',
#               'fiscal_year': 'N/A',
#               'score': 0.7223118450997543,
#               'year': '2023'}],
#  'sub_queries': ['Google cloud revenue 2022',
#                  'Google cloud revenue 2023',
#                  'Microsoft cloud revenue 2022',
#                  'Microsoft cloud revenue 2023',
#                  'NVIDIA data center revenue 2022',
#                  'NVIDIA data center revenue 2023']}
#
# --- Testing with a segment analysis query ---
#
# --- Decomposed Sub-queries for 'What percentage of Google's revenue came from cloud in 2023?': ---
#   1. Google revenue 2023
#   2. Google cloud revenue 2023
#   3. What percentage of Google's revenue came from cloud?
# --------------------------------------------------
#
# --- All Retrieved Chunks (before deduplication): ---
#   Company: GOOGL, Year: 2023, Score: 0.7572, Excerpt:  was $101.7 billion for the year ended December 31, 2023. • Capital expenditures, which primarily re...
#   Company: GOOGL, Year: 2024, Score: 0.7424, Excerpt: billion from 2023 to 2024. The growth was primarily driven by an increase in subscription revenues, ...
#   Company: GOOGL, Year: 2023, Score: 0.7134, Excerpt: te 2. Revenues Disaggregated Revenues The following table presents revenues disaggregated by type (i...
#   Company: GOOGL, Year: 2024, Score: 0.7840, Excerpt: billion from 2023 to 2024. The growth was primarily driven by an increase in subscription revenues, ...
#   Company: GOOGL, Year: 2023, Score: 0.7554, Excerpt: increased sales of Pixel devices. The decrease in platform revenues was primarily due to Google Play...
#   Company: GOOGL, Year: 2023, Score: 0.7230, Excerpt:  was $101.7 billion for the year ended December 31, 2023. • Capital expenditures, which primarily re...
#   Company: GOOGL, Year: 2024, Score: 0.7612, Excerpt: billion from 2023 to 2024. The growth was primarily driven by an increase in subscription revenues, ...
#   Company: GOOGL, Year: 2023, Score: 0.7358, Excerpt: increased sales of Pixel devices. The decrease in platform revenues was primarily due to Google Play...
#   Company: GOOGL, Year: 2022, Score: 0.7213, Excerpt:  the next 12 months. Positions that may be resolved include various U.S. and non-U.S. matters. Note ...
# ----------------------------------------------------
# {'answer': "Based on the provided context, we can determine that Google's "
#            'revenue for 2023 was $307.4 billion. However, we cannot determine '
#            "the exact percentage of Google's revenue that came from cloud in "
#            '2023 because the context does not provide this specific '
#            'information.\n'
#            '\n'
#            'However, we can find the revenue from Google Cloud in 2023, which '
#            'was $33.1 billion. We can also find the total revenue from Google '
#            'Services, which was $272.5 billion. Therefore, we can calculate '
#            'the percentage of revenue from Google Cloud as follows:\n'
#            '\n'
#            'Percentage of revenue from Google Cloud = (Revenue from Google '
#            'Cloud / Total revenue from Google Services) x 100%\n'
#            '= ($33.1 billion / $272.5 billion) x 100%\n'
#            '= 12.1%\n'
#            '\n'
#            "So, approximately 12.1% of Google's revenue in 2023 came from "
#            'Google Cloud.',
#  'query': "What percentage of Google's revenue came from cloud in 2023?",
#  'reasoning': 'Original query decomposed into 3 sub-queries.\n'
#               "Retrieving information for sub-query: 'Google revenue 2023'\n"
#               "Retrieving information for sub-query: 'Google cloud revenue "
#               "2023'\n"
#               "Retrieving information for sub-query: 'What percentage of "
#               "Google's revenue came from cloud?'\n"
#               'Used Groq model to synthesize answer from combined retrieved '
#               'context.',
#  'sources': [{'company': 'GOOGL',
#               'excerpt': 'billion from 2023 to 2024. The growth was primarily '
#                          'driven by an increase in subscription revenues, '
#                          'largely from growth in the number of paid '
#                          'subscribers for YouTube services followed by Google '
#                          'One. Google Cloud Google Cloud revenues increased '
#                          '$10.1 billion from 2023 to 2024 primarily driven by '
#                          'grow...',
#               'fiscal_year': 'N/A',
#               'score': 0.7839549047105683,
#               'year': '2024'},
#              {'company': 'GOOGL',
#               'excerpt': ' was $101.7 billion for the year ended December 31, '
#                          '2023. • Capital expenditures, which primarily '
#                          'reflected investments in technical infrastructure, '
#                          'were $32.3 billion for the year ended December 31, '
#                          '2023. • As of December\xa031, 2023, we had 182,502 '
#                          'employees. Financial Results Revenues The following '
#                          '...',
#               'fiscal_year': 'N/A',
#               'score': 0.7571989840215608,
#               'year': '2023'},
#              {'company': 'GOOGL',
#               'excerpt': 'increased sales of Pixel devices. The decrease in '
#                          'platform revenues was primarily due to Google Play, '
#                          'driven by the fee structure changes we announced in '
#                          '2021 as well as a decrease in buyer spending. '
#                          'Additionally, the overall increase in Google '
#                          'subscriptions, platforms, and devices revenues was '
#                          'adve...',
#               'fiscal_year': 'N/A',
#               'score': 0.7553930252987062,
#               'year': '2023'},
#              {'company': 'GOOGL',
#               'excerpt': ' the next 12 months. Positions that may be resolved '
#                          'include various U.S. and non-U.S. matters. Note 15. '
#                          'Information about Segments and Geographic Areas We '
#                          'report our segment results as Google Services, '
#                          'Google Cloud, and Other Bets: • Google Services '
#                          'includes products and services such as ads, '
#                          'Androi...',
#               'fiscal_year': 'N/A',
#               'score': 0.7213459563730283,
#               'year': '2022'},
#              {'company': 'GOOGL',
#               'excerpt': 'te 2. Revenues Disaggregated Revenues The following '
#                          'table presents revenues disaggregated by type (in '
#                          'millions): Year Ended December 31, 2021 2022 2023 '
#                          'Google Search & other $ 148,951 $ 162,450 $ 175,033 '
#                          'YouTube ads 28,845 29,243 31,510 Google Network '
#                          '31,701 32,780 31,312 Google advertising 209,497 ...',
#               'fiscal_year': 'N/A',
#               'score': 0.7134126303881417,
#               'year': '2023'}],
#  'sub_queries': ['Google revenue 2023',
#                  'Google cloud revenue 2023',
#                  "What percentage of Google's revenue came from cloud?"]}
#
# --- Testing with an AI Strategy query ---
#
# --- Decomposed Sub-queries for 'Compare AI investments mentioned by all three companies (Google, Microsoft, NVIDIA) in their 2024 10-Ks.': ---
#   1. Google AI investments 2024
#   2. Microsoft AI investments 2024
#   3. NVIDIA AI investments 2024
# --------------------------------------------------
#
# --- All Retrieved Chunks (before deduplication): ---
#   Company: GOOGL, Year: 2024, Score: 0.6817, Excerpt: as purpose-built agents for Search and our Customer Engagement Suite. AI has been used in Google Wor...
#   Company: GOOGL, Year: 2024, Score: 0.6603, Excerpt: tisers, partners, customers, and developers. We are using Gemini 2.0 in new research prototypes, inc...
#   Company: GOOGL, Year: 2023, Score: 0.6590, Excerpt: Smart Compose, and malware and phishing protection in Gmail. Duet AI in Google Workspace helps users...
#   Company: MSFT, Year: 2023, Score: 0.7256, Excerpt: e accompanying Notes to Financial Statements (Part II, Item 8 of this Form 10-K). This section gener...
#   Company: MSFT, Year: 2024, Score: 0.6842, Excerpt:  operations for the year ended June 30, 2024 compared to the year ended June 30, 2023. For a discuss...
#   Company: MSFT, Year: 2024, Score: 0.6647, Excerpt:  made. We undertake no obligation to update or revise publicly any forward-looking statements, wheth...
#   Company: NVDA, Year: 2022, Score: 0.6924, Excerpt: nd 123%, respectively, from a year ago. Cash, cash equivalents and marketable securities were $21.21...
#   Company: NVDA, Year: 2024, Score: 0.6923, Excerpt:  processors optimized for generative AI, LLMs and other AI workloads. We introduced NVIDIA DGX Cloud...
#   Company: NVDA, Year: 2024, Score: 0.6766, Excerpt: rom fiscal year 2023. In Gaming, we launched the GeForce RTX 4060 and 4070 GPUs based on the NVIDIA ...
# ----------------------------------------------------
# {'answer': 'Based on the provided context, here is a comprehensive answer '
#            'comparing AI investments mentioned by Google, Microsoft, and '
#            'NVIDIA in their 2024 10-Ks:\n'
#            '\n'
#            'Google:\n'
#            '\n'
#            '* Google is committed to making digital technology and artificial '
#            'intelligence (AI) available broadly and doing so responsibly.\n'
#            '* The company creates platforms and tools, powered by AI, that '
#            'deliver innovative solutions that meet the evolving needs of its '
#            'customers.\n'
#            "* Google's AI investments include:\n"
#            '\t+ Gemini 2.0, a new research prototype that explores the future '
#            'capabilities of a universal AI assistant.\n'
#            '\t+ Project Astra, an early prototype capable of taking actions in '
#            'Chrome as an experimental extension.\n'
#            '\t+ Vertex AI platform, which gives developers the ability to '
#            'train, tune, augment, and deploy applications using generative AI '
#            'models and services such as Enterprise Search and Conversations.\n'
#            '\t+ Duet AI for Google Cloud, which provides pre-packaged AI '
#            'agents that assist developers to write, test, document, and '
#            'operate software.\n'
#            '\n'
#            'Microsoft:\n'
#            '\n'
#            '* Microsoft is committed to making digital technology and '
#            'artificial intelligence (AI) available broadly and doing so '
#            'responsibly.\n'
#            '* The company creates platforms and tools, powered by AI, that '
#            'deliver innovative solutions that meet the evolving needs of its '
#            'customers.\n'
#            "* Microsoft's AI investments include:\n"
#            '\t+ AI-powered agents for Search and its Customer Engagement '
#            'Suite.\n'
#            '\t+ AI-powered natural language interactions to transform games '
#            'and launched DLSS 3.5 Ray Reconstruction.\n'
#            '\t+ NVIDIA Omniverse Cloud, a fully managed service running in '
#            'Microsoft Azure, for the development and deployment of industrial '
#            'metaverse applications.\n'
#            '\n'
#            'NVIDIA:\n'
#            '\n'
#            '* NVIDIA is a technology company that creates platforms and tools, '
#            'powered by AI, that deliver innovative solutions that meet the '
#            'evolving needs of its customers.\n'
#            "* The company's AI investments include:\n"
#            '\t+ NVIDIA Omniverse Enterprise, a platform that enables the '
#            'creation of industrial metaverse applications.\n'
#            '\t+ NVIDIA Quantum-2 400Gbps switch and end-to-end networking '
#            'platform.\n'
#            '\t+ NVIDIA Jetson AGX Orin for edge AI and autonomous machines.\n'
#            '\t+ NVIDIA DGX Cloud and AI Foundations to help businesses create '
#            'and operate custom large language models and generative AI '
#            'models.\n'
#            '\n'
#            'Comparison:\n'
#            '\n'
#            '* All three companies are committed to making digital technology '
#            'and artificial intelligence (AI) available broadly and doing so '
#            'responsibly.\n'
#            '* Google, Microsoft, and NVIDIA are investing in various AI '
#            'technologies, including natural language processing, computer '
#            'vision, and machine learning.\n'
#            "* Google's AI investments focus on developing AI-powered agents "
#            'for Search and its Customer Engagement Suite, as well as its '
#            'Vertex AI platform and Duet AI for Google Cloud.\n'
#            "* Microsoft's AI investments focus on developing AI-powered agents "
#            'for Search and its Customer Engagement Suite, as well as its '
#            'NVIDIA Omniverse Cloud and AI-powered natural language '
#            'interactions.\n'
#            "* NVIDIA's AI investments focus on developing NVIDIA Omniverse "
#            'Enterprise, NVIDIA Quantum-2 400Gbps switch and end-to-end '
#            'networking platform, NVIDIA Jetson AGX Orin for edge AI and '
#            'autonomous machines, and NVIDIA DGX Cloud and AI Foundations.\n'
#            '\n'
#            'In terms of specific figures and growth rates, the provided '
#            "context does not provide detailed information on the companies' AI "
#            "investments. However, it does mention that Google's AI investments "
#            'are focused on developing AI-powered agents for Search and its '
#            'Customer Engagement Suite, as well as its Vertex AI platform and '
#            'Duet AI for Google Cloud.',
#  'query': 'Compare AI investments mentioned by all three companies (Google, '
#           'Microsoft, NVIDIA) in their 2024 10-Ks.',
#  'reasoning': 'Original query decomposed into 3 sub-queries.\n'
#               "Retrieving information for sub-query: 'Google AI investments "
#               "2024'\n"
#               "Retrieving information for sub-query: 'Microsoft AI investments "
#               "2024'\n"
#               "Retrieving information for sub-query: 'NVIDIA AI investments "
#               "2024'\n"
#               'Used Groq model to synthesize answer from combined retrieved '
#               'context.',
#  'sources': [{'company': 'MSFT',
#               'excerpt': 'e accompanying Notes to Financial Statements (Part '
#                          'II, Item 8 of this Form 10-K). This section '
#                          'generally discusses the results of our operations '
#                          'for the year ended June 30, 2023 compared to the '
#                          'year ended June 30, 2022. For a discussion of the '
#                          'year ended June 30 , 2022 compared to the year ended '
#                          'Jun...',
#               'fiscal_year': 'N/A',
#               'score': 0.7256255920054642,
#               'year': '2023'},
#              {'company': 'NVDA',
#               'excerpt': 'nd 123%, respectively, from a year ago. Cash, cash '
#                          'equivalents and marketable securities were $21.21 '
#                          'billion, up from $11.56 billion a year earlier. The '
#                          'increase reflects operating cash flow generation and '
#                          '$5.00 billion of debt issuance proceeds. We paid '
#                          '$399 million in quarterly cash dividends in f...',
#               'fiscal_year': 'N/A',
#               'score': 0.6924349278704713,
#               'year': '2022'},
#              {'company': 'NVDA',
#               'excerpt': ' processors optimized for generative AI, LLMs and '
#                          'other AI workloads. We introduced NVIDIA DGX Cloud '
#                          'and AI Foundations to help businesses create and '
#                          'operate custom large language models and generative '
#                          'AI models. As AV algorithms move to video '
#                          'transformers, and more cars are equipped with '
#                          'cameras, w...',
#               'fiscal_year': 'N/A',
#               'score': 0.6922540309041734,
#               'year': '2024'},
#              {'company': 'MSFT',
#               'excerpt': ' operations for the year ended June 30, 2024 '
#                          'compared to the year ended June 30, 2023. For a '
#                          'discussion of the year ended June 30, 2023 compared '
#                          'to the year ended June 30, 2022, please refer to '
#                          'Part II, Item 7, “Management’s Discussion and '
#                          'Analysis of Financial Condition and Results of '
#                          'Operations” i...',
#               'fiscal_year': 'N/A',
#               'score': 0.6842010752092356,
#               'year': '2024'},
#              {'company': 'GOOGL',
#               'excerpt': 'as purpose-built agents for Search and our Customer '
#                          'Engagement Suite. AI has been used in Google '
#                          'Workspace for years to improve grammar, efficiency, '
#                          'security, and more with features like Smart Reply, '
#                          'Smart Compose, and malware and phishing protection '
#                          'in Gmail. Now, Gemini for Google Workspace brings...',
#               'fiscal_year': 'N/A',
#               'score': 0.6816846318299215,
#               'year': '2024'},
#              {'company': 'NVDA',
#               'excerpt': 'rom fiscal year 2023. In Gaming, we launched the '
#                          'GeForce RTX 4060 and 4070 GPUs based on the NVIDIA '
#                          'Ada Lovelace architecture. We announced NVIDIA '
#                          'Avatar Cloud Engine for Games, a custom AI model '
#                          'foundry service using AI-powered natural language '
#                          'interactions to transform games and launched DLSS '
#                          '3.5 ...',
#               'fiscal_year': 'N/A',
#               'score': 0.6765549214091418,
#               'year': '2024'},
#              {'company': 'MSFT',
#               'excerpt': ' made. We undertake no obligation to update or '
#                          'revise publicly any forward-looking statements, '
#                          'whether because of new information, future events, '
#                          'or otherwise. PART I ITEM 1. B USINESS GENERAL '
#                          'Embracing Our Future Microsoft is a technology '
#                          'company committed to making digital technology and '
#                          'artificia...',
#               'fiscal_year': 'N/A',
#               'score': 0.6646551484820902,
#               'year': '2024'},
#              {'company': 'GOOGL',
#               'excerpt': 'tisers, partners, customers, and developers. We are '
#                          'using Gemini 2.0 in new research prototypes, '
#                          'including Project Astra, which explores the future '
#                          'capabilities of a universal AI assistant and Project '
#                          'Mariner, an early prototype capable of taking '
#                          'actions in Chrome as an experimental extension. We '
#                          'be...',
#               'fiscal_year': 'N/A',
#               'score': 0.6603081483840163,
#               'year': '2024'},
#              {'company': 'GOOGL',
#               'excerpt': 'Smart Compose, and malware and phishing protection '
#                          'in Gmail. Duet AI in Google Workspace helps users '
#                          'write, organize, visualize, accelerate workflows, '
#                          'and have richer meetings. • AI Platform and Duet AI '
#                          'for Google Cloud: Our Vertex AI platform gives '
#                          'developers the ability to train, tune, augment, '
#                          'an...',
#               'fiscal_year': 'N/A',
#               'score': 0.6589874255166052,
#               'year': '2023'}],
#  'sub_queries': ['Google AI investments 2024',
#                  'Microsoft AI investments 2024',
#                  'NVIDIA AI investments 2024']}
#
# --- Testing with a Basic Metrics query ---
#  Querying agent: What was Microsoft's total revenue in 2023?
#
# --- Decomposed Sub-queries for 'What was Microsoft's total revenue in 2023?': ---
#   1. What was Microsoft's total revenue in 2023?
# --------------------------------------------------
#
# --- All Retrieved Chunks (before deduplication): ---
#   Company: MSFT, Year: 2022, Score: 0.7022, Excerpt: ings, was as follows: (In millions) Year Ended June 30, 2022 2021 2020 Server products and cloud ser...
#   Company: MSFT, Year: 2022, Score: 0.6913, Excerpt: th fiscal year 2021 included: • Microsoft Cloud (formerly commercial cloud) revenue increased 32% to...
#   Company: MSFT, Year: 2024, Score: 0.6869, Excerpt: d cloud services revenue growth Revenue from Windows Commercial products and cloud services, compris...
# ----------------------------------------------------
#
# --- Decomposed Sub-queries: ---
#   - What was Microsoft's total revenue in 2023?
# --------------------------------------------------
#
#  Final Answer:
# {
#   "query": "What was Microsoft's total revenue in 2023?",
#   "answer": "Based on the provided context from Microsoft's 10-K filings, the total revenue for 2023 is not explicitly stated. However, we can infer the total revenue for 2023 from the provided information.\n\nThe total revenue for 2022 is $198,270 million, and the total revenue for 2024 is $245,122 million. To find the total revenue for 2023, we can use the percentage change in revenue between 2022 and 2024.\n\nThe percentage change in revenue between 2022 and 2024 is 16% ($245,122 million - $198,270 million) / $198,270 million. To find the total revenue for 2023, we can multiply the total revenue for 2022 by (1 + 0.16) or 1.16.\n\nTotal revenue for 2023 = $198,270 million x 1.16 = $230,111 million\n\nTherefore, the total revenue for Microsoft in 2023 is approximately $230,111 million.",
#   "reasoning": "Original query processed as a single search.\nRetrieving information for sub-query: 'What was Microsoft's total revenue in 2023?'\nUsed Groq model to synthesize answer from combined retrieved context.",
#   "sub_queries": [
#     "What was Microsoft's total revenue in 2023?"
#   ],
#   "sources": [
#     {
#       "company": "MSFT",
#       "year": "2022",
#       "fiscal_year": "N/A",
#       "excerpt": "ings, was as follows: (In millions) Year Ended June\u00a030, 2022 2021 2020 Server products and cloud services $ 67,321 $ 52,589 $ 41,379 Office products and cloud services 44,862 39,872 35,316 Windows 24,761 22,488 21,510 Gaming 16,230 15,370 11,575 LinkedIn 13,816 10,289 8,077 Search and news advertisi...",
#       "score": 0.70220318518741
#     },
#     {
#       "company": "MSFT",
#       "year": "2022",
#       "fiscal_year": "N/A",
#       "excerpt": "th fiscal year 2021 included: \u2022 Microsoft Cloud (formerly commercial cloud) revenue increased 32% to $91.2 billion. \u2022 Office Commercial products and cloud services revenue increased 13% driven by Office 365 Commercial growth of 18%. \u2022 Office Consumer products and cloud services revenue increased 11%...",
#       "score": 0.6912652576607645
#     },
#     {
#       "company": "MSFT",
#       "year": "2024",
#       "fiscal_year": "N/A",
#       "excerpt": "d cloud services revenue growth Revenue from Windows Commercial products and cloud services, comprising volume licensing of the Windows operating system, Windows cloud services, and other Windows commercial offerings Devices revenue growth Revenue from Devices, including Surface, HoloLens, and PC ac...",
#       "score": 0.6869078033537748
#     }
#   ]
# }
#
#  Response saved to C:\Users\Sai Vaishnavi\Downloads\Intern project\src\sample_outputs\microsoft_revenue_2023.json
#
# --- Testing with a YoY Comparison query ---
#  Querying agent: How did NVIDIA's data center revenue grow from 2022 to 2023?
#
# --- Decomposed Sub-queries for 'How did NVIDIA's data center revenue grow from 2022 to 2023?': ---
#   1. NVIDIA data center revenue 2022
#   2. NVIDIA data center revenue 2023
# --------------------------------------------------
#
# --- All Retrieved Chunks (before deduplication): ---
#   Company: NVDA, Year: 2023, Score: 0.7474, Excerpt: and and $1.13 billion for inventory purchase obligations in excess of our demand expectations. Opera...
#   Company: NVDA, Year: 2024, Score: 0.7408, Excerpt:  "Compute & Networking" and "Graphics." Refer to Note 17 of the Notes to the Consolidated Financial ...
#   Company: NVDA, Year: 2024, Score: 0.7397, Excerpt:  Data Center, Gaming, Professional Visualization, and Automotive. Revenue for fiscal year 2024 was $...
#   Company: NVDA, Year: 2023, Score: 0.7567, Excerpt: and and $1.13 billion for inventory purchase obligations in excess of our demand expectations. Opera...
#   Company: NVDA, Year: 2024, Score: 0.7457, Excerpt:  "Compute & Networking" and "Graphics." Refer to Note 17 of the Notes to the Consolidated Financial ...
#   Company: NVDA, Year: 2024, Score: 0.7379, Excerpt:  Data Center, Gaming, Professional Visualization, and Automotive. Revenue for fiscal year 2024 was $...
# ----------------------------------------------------
#
# --- Decomposed Sub-queries: ---
#   - NVIDIA data center revenue 2022
#   - NVIDIA data center revenue 2023
# --------------------------------------------------
#
#  Final Answer:
# {
#   "query": "How did NVIDIA's data center revenue grow from 2022 to 2023?",
# ...
#       "score": 0.49741064097403587
#     },
#     {
#       "company": "MSFT",
#       "year": "2023",
#       "fiscal_year": "N/A",
#       "excerpt": "y growth in Intelligent Cloud and Productivity and Business Processes and the change in accounting estimate, offset in part by a decline in More Personal Computing. \u2022 Gross margin percentage increased slightly. Excluding the impact of the change in accounting estimate, gross margin percentage decrea...",
#       "score": 0.4970111102779981
#     }
#   ]
# }
#
#  Response saved to C:\Users\Sai Vaishnavi\Downloads\Intern project\src\sample_outputs\highest_operating_margin_2023.json
#
# --- Testing with a Segment Analysis query ---
#  Querying agent: What percentage of Google's revenue came from cloud in 2023?
#
# --- Decomposed Sub-queries for 'What percentage of Google's revenue came from cloud in 2023?': ---
#   1. Google cloud revenue 2023
#   2. Google total revenue 2023
# --------------------------------------------------
#
# --- All Retrieved Chunks (before deduplication): ---
#   Company: GOOGL, Year: 2024, Score: 0.7840, Excerpt: billion from 2023 to 2024. The growth was primarily driven by an increase in subscription revenues, ...
#   Company: GOOGL, Year: 2023, Score: 0.7554, Excerpt: increased sales of Pixel devices. The decrease in platform revenues was primarily due to Google Play...
#   Company: GOOGL, Year: 2023, Score: 0.7230, Excerpt:  was $101.7 billion for the year ended December 31, 2023. • Capital expenditures, which primarily re...
#   Company: GOOGL, Year: 2023, Score: 0.7661, Excerpt:  was $101.7 billion for the year ended December 31, 2023. • Capital expenditures, which primarily re...
#   Company: GOOGL, Year: 2024, Score: 0.7462, Excerpt: billion from 2023 to 2024. The growth was primarily driven by an increase in subscription revenues, ...
#   Company: GOOGL, Year: 2022, Score: 0.7299, Excerpt:  of Alphabet's corporate costs, reflecting its increasing collaboration with Google Services, Google...
# ----------------------------------------------------
#
# --- Decomposed Sub-queries: ---
#   - Google cloud revenue 2023
#   - Google total revenue 2023
# --------------------------------------------------
#
#  Final Answer:
# {
#   "query": "What percentage of Google's revenue came from cloud in 2023?",
#   "answer": "Based on the provided context, we can determine that Google's revenue for 2023 was $307.4 billion. However, we cannot determine the percentage of Google's revenue that came from cloud in 2023 because the context does not provide the specific revenue figure for Google Cloud in 2023.\n\nHowever, we can find the revenue figure for Google Cloud in 2023, which is $33.1 billion. To calculate the percentage of Google's revenue that came from cloud in 2023, we can divide the revenue figure for Google Cloud by the total revenue for 2023 and multiply by 100.\n\n($33.1 billion \u00f7 $307.4 billion) x 100 = 10.8%\n\nTherefore, approximately 10.8% of Google's revenue in 2023 came from cloud services.",
#   "reasoning": "Original query decomposed into 2 sub-queries.\nRetrieving information for sub-query: 'Google cloud revenue 2023'\nRetrieving information for sub-query: 'Google total revenue 2023'\nUsed Groq model to synthesize answer from combined retrieved context.",
#   "sub_queries": [
#     "Google cloud revenue 2023",
#     "Google total revenue 2023"
#   ],
#   "sources": [
#     {
#       "company": "GOOGL",
#       "year": "2024",
#       "fiscal_year": "N/A",
#       "excerpt": "billion from 2023 to 2024. The growth was primarily driven by an increase in subscription revenues, largely from growth in the number of paid subscribers for YouTube services followed by Google One. Google Cloud Google Cloud revenues increased $10.1 billion from 2023 to 2024 primarily driven by grow...",
#       "score": 0.7839549047105683
#     },
#     {
#       "company": "GOOGL",
#       "year": "2023",
#       "fiscal_year": "N/A",
#       "excerpt": " was $101.7 billion for the year ended December 31, 2023. \u2022 Capital expenditures, which primarily reflected investments in technical infrastructure, were $32.3 billion for the year ended December 31, 2023. \u2022 As of December\u00a031, 2023, we had 182,502 employees. Financial Results Revenues The following ...",
#       "score": 0.7660724426933061
#     },
#     {
#       "company": "GOOGL",
#       "year": "2023",
#       "fiscal_year": "N/A",
#       "excerpt": "increased sales of Pixel devices. The decrease in platform revenues was primarily due to Google Play, driven by the fee structure changes we announced in 2021 as well as a decrease in buyer spending. Additionally, the overall increase in Google subscriptions, platforms, and devices revenues was adve...",
#       "score": 0.7553930252987062
#     },
#     {
#       "company": "GOOGL",
#       "year": "2022",
#       "fiscal_year": "N/A",
#       "excerpt": " of Alphabet's corporate costs, reflecting its increasing collaboration with Google Services, Google Cloud, and Other Bets. Prior periods will be recast to conform to the revised presentation. See Note 15 of the Notes to Consolidated Financial Statements included in Item 8 of this Annual Report on F...",
#       "score": 0.7299224391149921
#     }
#   ]
# }
#
#  Response saved to C:\Users\Sai Vaishnavi\Downloads\Intern project\src\sample_outputs\google_cloud_revenue_percentage_2023.json
#
# --- Testing with a AI Strategy query ---
#  Querying agent: Compare AI investments mentioned by all three companies (Google, Microsoft, NVIDIA) in their 2024 10-Ks.
#
# --- Decomposed Sub-queries for 'Compare AI investments mentioned by all three companies (Google, Microsoft, NVIDIA) in their 2024 10-Ks.': ---
#   1. Google AI investments 2024
#   2. Microsoft AI investments 2024
#   3. NVIDIA AI investments 2024
# --------------------------------------------------
#
# --- All Retrieved Chunks (before deduplication): ---
#   Company: GOOGL, Year: 2024, Score: 0.6817, Excerpt: as purpose-built agents for Search and our Customer Engagement Suite. AI has been used in Google Wor...
#   Company: GOOGL, Year: 2024, Score: 0.6603, Excerpt: tisers, partners, customers, and developers. We are using Gemini 2.0 in new research prototypes, inc...
#   Company: GOOGL, Year: 2023, Score: 0.6590, Excerpt: Smart Compose, and malware and phishing protection in Gmail. Duet AI in Google Workspace helps users...
#   Company: MSFT, Year: 2023, Score: 0.7256, Excerpt: e accompanying Notes to Financial Statements (Part II, Item 8 of this Form 10-K). This section gener...
#   Company: MSFT, Year: 2024, Score: 0.6842, Excerpt:  operations for the year ended June 30, 2024 compared to the year ended June 30, 2023. For a discuss...
#   Company: MSFT, Year: 2024, Score: 0.6647, Excerpt:  made. We undertake no obligation to update or revise publicly any forward-looking statements, wheth...
#   Company: NVDA, Year: 2022, Score: 0.6924, Excerpt: nd 123%, respectively, from a year ago. Cash, cash equivalents and marketable securities were $21.21...
#   Company: NVDA, Year: 2024, Score: 0.6923, Excerpt:  processors optimized for generative AI, LLMs and other AI workloads. We introduced NVIDIA DGX Cloud...
#   Company: NVDA, Year: 2024, Score: 0.6766, Excerpt: rom fiscal year 2023. In Gaming, we launched the GeForce RTX 4060 and 4070 GPUs based on the NVIDIA ...
# ----------------------------------------------------
#
# --- Decomposed Sub-queries: ---
#   - Google AI investments 2024
#   - Microsoft AI investments 2024
#   - NVIDIA AI investments 2024
# --------------------------------------------------
#
#  Final Answer:
# {
#   "query": "Compare AI investments mentioned by all three companies (Google, Microsoft, NVIDIA) in their 2024 10-Ks.",
#   "answer": "Based on the provided context, here is a comprehensive answer comparing AI investments mentioned by Google, Microsoft, and NVIDIA in their 2024 10-Ks:\n\nGoogle:\n\n* Google is committed to making digital technology and artificial intelligence (AI) available broadly and doing so responsibly.\n* The company creates platforms and tools, powered by AI, that deliver innovative solutions that meet the evolving needs of its customers.\n* Google's AI investments include:\n\t+ Gemini 2.0, a new research prototype that explores the future capabilities of a universal AI assistant.\n\t+ Project Astra, an early prototype capable of taking actions in Chrome as an experimental extension.\n\t+ Vertex AI platform, which gives developers the ability to train, tune, augment, and deploy applications using generative AI models and services such as Enterprise Search and Conversations.\n\t+ Duet AI for Google Cloud, which provides pre-packaged AI agents that assist developers to write, test, document, and operate software.\n\nMicrosoft:\n\n* Microsoft is committed to making digital technology and artificial intelligence (AI) available broadly and doing so responsibly.\n* The company creates platforms and tools, powered by AI, that deliver innovative solutions that meet the evolving needs of its customers.\n* Microsoft's AI investments include:\n\t+ AI-powered agents for Search and its Customer Engagement Suite.\n\t+ AI-powered natural language interactions to transform games and launched DLSS 3.5 Ray Reconstruction.\n\t+ NVIDIA Omniverse Cloud, a fully managed service running in Microsoft Azure, for the development and deployment of industrial metaverse applications.\n\nNVIDIA:\n\n* NVIDIA is a technology company that creates platforms and tools, powered by AI, that deliver innovative solutions that meet the evolving needs of its customers.\n* The company's AI investments include:\n\t+ NVIDIA Omniverse Enterprise, a platform that enables the creation of industrial metaverse applications.\n\t+ NVIDIA Quantum-2 400Gbps switch and end-to-end networking platform.\n\t+ NVIDIA Jetson AGX Orin for edge AI and autonomous machines.\n\t+ NVIDIA DGX Cloud and AI Foundations to help businesses create and operate custom large language models and generative AI models.\n\nComparison:\n\n* All three companies are committed to making digital technology and artificial intelligence (AI) available broadly and doing so responsibly.\n* Google, Microsoft, and NVIDIA are investing in various AI technologies, including natural language processing, computer vision, and machine learning.\n* Google's AI investments focus on developing AI-powered agents for Search and its Customer Engagement Suite, as well as its Vertex AI platform and Duet AI for Google Cloud.\n* Microsoft's AI investments focus on developing AI-powered agents for Search and its Customer Engagement Suite, as well as its NVIDIA Omniverse Cloud and AI-powered natural language interactions.\n* NVIDIA's AI investments focus on developing NVIDIA Omniverse Enterprise, NVIDIA Quantum-2 400Gbps switch and end-to-end networking platform, NVIDIA Jetson AGX Orin for edge AI and autonomous machines, and NVIDIA DGX Cloud and AI Foundations.\n\nIn terms of specific figures and growth rates, the provided context does not provide detailed information on the companies' AI investments. However, it does mention that Google's AI investments are focused on developing AI-powered agents for Search and its Customer Engagement Suite, as well as its Vertex AI platform and Duet AI for Google Cloud.",
#   "reasoning": "Original query decomposed into 3 sub-queries.\nRetrieving information for sub-query: 'Google AI investments 2024'\nRetrieving information for sub-query: 'Microsoft AI investments 2024'\nRetrieving information for sub-query: 'NVIDIA AI investments 2024'\nUsed Groq model to synthesize answer from combined retrieved context.",
#   "sub_queries": [
#     "Google AI investments 2024",
#     "Microsoft AI investments 2024",
#     "NVIDIA AI investments 2024"
#   ],
#   "sources": [
#     {
#       "company": "MSFT",
#       "year": "2023",
#       "fiscal_year": "N/A",
#       "excerpt": "e accompanying Notes to Financial Statements (Part II, Item 8 of this Form 10-K). This section generally discusses the results of our operations for the year ended June 30, 2023 compared to the year ended June 30, 2022. For a discussion of the year ended June 30 , 2022 compared to the year ended Jun...",
#       "score": 0.7256255920054642
#     },
#     {
#       "company": "NVDA",
#       "year": "2022",
#       "fiscal_year": "N/A",
#       "excerpt": "nd 123%, respectively, from a year ago. Cash, cash equivalents and marketable securities were $21.21 billion, up from $11.56 billion a year earlier. The increase reflects operating cash flow generation and $5.00 billion of debt issuance proceeds. We paid $399 million in quarterly cash dividends in f...",
#       "score": 0.6924349278704713
#     },
#     {
#       "company": "NVDA",
#       "year": "2024",
#       "fiscal_year": "N/A",
#       "excerpt": " processors optimized for generative AI, LLMs and other AI workloads. We introduced NVIDIA DGX Cloud and AI Foundations to help businesses create and operate custom large language models and generative AI models. As AV algorithms move to video transformers, and more cars are equipped with cameras, w...",
#       "score": 0.6922540309041734
#     },
#     {
#       "company": "MSFT",
#       "year": "2024",
#       "fiscal_year": "N/A",
#       "excerpt": " operations for the year ended June 30, 2024 compared to the year ended June 30, 2023. For a discussion of the year ended June 30, 2023 compared to the year ended June 30, 2022, please refer to Part II, Item 7, \u201cManagement\u2019s Discussion and Analysis of Financial Condition and Results of Operations\u201d i...",
#       "score": 0.6842010752092356
#     },
#     {
#       "company": "GOOGL",
#       "year": "2024",
#       "fiscal_year": "N/A",
#       "excerpt": "as purpose-built agents for Search and our Customer Engagement Suite. AI has been used in Google Workspace for years to improve grammar, efficiency, security, and more with features like Smart Reply, Smart Compose, and malware and phishing protection in Gmail. Now, Gemini for Google Workspace brings...",
#       "score": 0.6816846318299215
#     },
#     {
#       "company": "NVDA",
#       "year": "2024",
#       "fiscal_year": "N/A",
#       "excerpt": "rom fiscal year 2023. In Gaming, we launched the GeForce RTX 4060 and 4070 GPUs based on the NVIDIA Ada Lovelace architecture. We announced NVIDIA Avatar Cloud Engine for Games, a custom AI model foundry service using AI-powered natural language interactions to transform games and launched DLSS 3.5 ...",
#       "score": 0.6765549214091418
#     },
#     {
#       "company": "MSFT",
#       "year": "2024",
#       "fiscal_year": "N/A",
#       "excerpt": " made. We undertake no obligation to update or revise publicly any forward-looking statements, whether because of new information, future events, or otherwise. PART I ITEM 1. B USINESS GENERAL Embracing Our Future Microsoft is a technology company committed to making digital technology and artificia...",
#       "score": 0.6646551484820902
#     },
#     {
#       "company": "GOOGL",
#       "year": "2024",
#       "fiscal_year": "N/A",
#       "excerpt": "tisers, partners, customers, and developers. We are using Gemini 2.0 in new research prototypes, including Project Astra, which explores the future capabilities of a universal AI assistant and Project Mariner, an early prototype capable of taking actions in Chrome as an experimental extension. We be...",
#       "score": 0.6603081483840163
#     },
#     {
#       "company": "GOOGL",
#       "year": "2023",
#       "fiscal_year": "N/A",
#       "excerpt": "Smart Compose, and malware and phishing protection in Gmail. Duet AI in Google Workspace helps users write, organize, visualize, accelerate workflows, and have richer meetings. \u2022 AI Platform and Duet AI for Google Cloud: Our Vertex AI platform gives developers the ability to train, tune, augment, an...",
#       "score": 0.6589874255166052
#     }
#   ]
# }
#
#  Response saved to C:\Users\Sai Vaishnavi\Downloads\Intern project\src\sample_outputs\ai_investments_comparison_2024.json
#
# --- Main Pipeline Finished ---
